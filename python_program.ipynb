# %%
import numpy as np
import pandas as pd
df = pd.read_csv("C:/Users/Hp/Desktop/Data Science/hamoye.csv", encoding = "latin-1")

# %%
df.head()
# Out:
#    Area Code     Area  Item Code         Item  Element Code  \
# 0          4  Algeria       2501   Population           511
# 1          4  Algeria       2501   Population          5301
# 2          4  Algeria       2901  Grand Total           664
# 3          4  Algeria       2901  Grand Total           674
# 4          4  Algeria       2901  Grand Total           684
#
#                                   Element             Unit     Y2014  \
# 0           Total Population - Both sexes     1000 persons  38924.00
# 1                Domestic supply quantity      1000 tonnes      0.00
# 2           Food supply (kcal/capita/day)  kcal/capita/day   3377.00
# 3  Protein supply quantity (g/capita/day)     g/capita/day     94.90
# 4      Fat supply quantity (g/capita/day)     g/capita/day     80.06
#
#       Y2015     Y2016     Y2017     Y2018
# 0  39728.00  40551.00  41389.00  42228.00
# 1      0.00      0.00      0.00      0.00
# 2   3379.00   3372.00   3341.00   3322.00
# ...

# %%
df['Y2017'].mean()
# Out:
# 140.9177648602722

# %%
df['Y2017'].std()
# Out:
# 1671.8623590567995

# %%
df['Area'].nunique()
# Out:
# 49

# %%
df[(df['Area'] == 'Madagascar')& (df['Element'] == 'Protein supply quantity (g/capita/day)')].sum()
# Out:
# Area Code                                                   14319
# Area            MadagascarMadagascarMadagascarMadagascarMadaga...
# Item Code                                                  299405
# Item            Grand TotalVegetal ProductsAnimal ProductsCere...
# Element Code                                                74814
# Element         Protein supply quantity (g/capita/day)Protein ...
# Unit            g/capita/dayg/capita/dayg/capita/dayg/capita/d...
# Y2014                                                      177.79
# Y2015                                                      173.05
# Y2016                                                       173.4
# Y2017                                                      175.75
# Y2018                                                      176.64
# dtype: object

# %%
df['Y2014'].isnull().sum()
# Out:
# 1589

# %%
wine_df = df[df['Item'] == 'Wine']
wine_df.groupby('Item')[['Y2015','Y2018']].sum()
# Out:
#         Y2015    Y2018
# Item
# Wine  4251.81  4039.32

# %%
df.groupby('Area')[['Y2017','Area']].sum().sort_values(by='Y2017',ascending=False)
# Out:
#                                   Y2017  \
# Area
# Nigeria                      1483268.23
# Egypt                         866379.92
# South Africa                  517590.54
# Ethiopia                      448683.76
# Morocco                       388495.36
# Ghana                         337599.06
# Algeria                       325644.27
# United Republic of Tanzania   322616.85
# Kenya                         264660.66
# Sudan                         239931.92
# Cameroon                      232030.43
# Angola                        229159.57
# Côte d'Ivoire                 224599.01
# Uganda                        213950.38
# Malawi                        181098.71
# Mozambique                    161407.98
# Mauritania                    156665.46
# Mali                          149928.33
# Madagascar                    131197.73
# Niger                         126707.58
# Benin                         124771.22
# Tunisia                       124167.20
# ...

# %%
df.groupby('Area')[['Y2017','Area']].sum().sort_values(by='Y2017',ascending=True)
# Out:
#                                   Y2017  \
# Area
# Sudan (former)                     0.00
# Ethiopia PDR                       0.00
# Comoros                           59.84
# Seychelles                       442.34
# Sao Tome and Principe          12662.63
# Cabo Verde                     14650.74
# Guinea-Bissau                  19102.77
# Lesotho                        21267.96
# Botswana                       22101.30
# Djibouti                       22729.91
# Gambia                         23154.18
# Gabon                          27979.64
# Liberia                        29342.20
# Namibia                        29874.89
# Central African Republic       29937.00
# Congo                          41181.68
# Togo                           49841.88
# Mauritius                      51114.83
# Eswatini                       54343.33
# Sierra Leone                   55311.33
# Chad                           71594.68
# Rwanda                         73663.69
# ...

# %%
stock_variation_df = df[df['Element'] == 'Stock Variation']
stock_sum = stock_variation_df.groupby('Element').sum()
stock_sum
# Out:
#                  Area Code                                               Area  \
# Element
# Stock Variation     571566  AlgeriaAlgeriaAlgeriaAlgeriaAlgeriaAlgeriaAlge...
#
#                  Item Code                                               Item  \
# Element
# Stock Variation   11329527  Cereals - Excluding BeerWheat and productsRice...
#
#                  Element Code  \
# Element
# Stock Variation      21464704
#
#                                                               Unit     Y2014  \
# Element
# Stock Variation  1000 tonnes1000 tonnes1000 tonnes1000 tonnes10...  58749.83
#
#                     Y2015     Y2016     Y2017     Y2018
# Element
# Stock Variation  34910.99  33140.12  54316.91  20577.91

# %%
sp_df = df[df['Element'] == 'Processing']
sp_sum = sp_df.groupby('Element').sum()
sp_sum
# Out:
#             Area Code                                               Area  \
# Element
# Processing     271940  AlgeriaAlgeriaAlgeriaAlgeriaAlgeriaAlgeriaAlge...
#
#             Item Code                                               Item  \
# Element
# Processing    5350416  Cereals - Excluding BeerWheat and productsRice...
#
#             Element Code                                               Unit  \
# Element
# Processing      10313310  1000 tonnes1000 tonnes1000 tonnes1000 tonnes10...
#
#                Y2014     Y2015     Y2016     Y2017     Y2018
# Element
# Processing  282923.0  287929.0  280631.0  292836.0  308429.0
